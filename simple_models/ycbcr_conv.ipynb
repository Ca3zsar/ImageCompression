# %%
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

import tensorflow.keras
import numpy as np
import tensorflow as tf

# tf.config.run_functions_eagerly(False)
# Out:
# 2024-04-19 01:55:35.387907: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-19 01:55:35.488470: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-19 01:55:36.547681: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
BINARY_SIZE = 2
PATCH_SIZE = 8
BATCH_SIZE = 256

# %%
def load_keras_dataset(dataset_name):
    import keras.datasets as datasets
    (x_train, _), (x_test, _) = getattr(datasets, dataset_name).load_data()

    x_train = np.append(x_train, x_test, axis=0)
    x_train = x_train.astype('float32') / 255.
    return x_train

def load_stl10():
    path = "data/stl10/train_X.bin"

    with open(path, 'rb') as f:
        data = np.fromfile(f, dtype=np.uint8)
        data = data.reshape(-1, 3, 96, 96)
        data = np.transpose(data, (0, 3, 2, 1))
        data = data.astype('float32') / 255.
    return data


def get_data():
    cifar10_dataset = load_keras_dataset('cifar10')
    cifar100_dataset = load_keras_dataset('cifar100')

    # append the datasets
    dataset = np.append(cifar10_dataset, cifar100_dataset, axis=0)
    
    return dataset

def get_validation_data():
    cifar100_dataset = load_keras_dataset('cifar100')[:500]

    return cifar100_dataset

def get_simple_data():
    cifar10_dataset = load_keras_dataset('cifar10')

    return cifar10_dataset

# %%
dataset = get_simple_data()
val_dataset = get_validation_data()

# %%
dataset.shape
# Out:
# (60000, 32, 32, 3)

# %%
# dataset to ycbcr
dataset = tf.image.rgb_to_yuv(dataset)
val_dataset = tf.image.rgb_to_yuv(val_dataset)
# Out:
# 2024-04-19 01:55:40.091174: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.170959: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.171047: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.176206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.176305: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.176327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.403579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.403789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.403820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-04-19 01:55:40.403895: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-19 01:55:40.403972: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-04-19 01:55:40.403992: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:226] Using CUDA malloc Async allocator for GPU: 0
# 2024-04-19 01:55:40.404376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1753 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-04-19 01:55:42.139145: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
# tf.compat.v1.disable_eager_execution()
image_input = tensorflow.keras.layers.Input(shape=(None, None, 3))
x = tensorflow.keras.layers.Conv2D(32, (3, 3), padding='same')(image_input)
x = tensorflow.keras.layers.LeakyReLU()(x)
x = tensorflow.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tensorflow.keras.layers.Conv2D(64, (3, 3), padding='same')(x)
x = tensorflow.keras.layers.LeakyReLU()(x)
x = tensorflow.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tensorflow.keras.layers.Conv2D(128, (3, 3), padding='same')(x)
x = tensorflow.keras.layers.LeakyReLU()(x)
x = tensorflow.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tensorflow.keras.layers.Conv2D(BINARY_SIZE, (3, 3), padding='same')(x)
encoded = tensorflow.keras.layers.LeakyReLU()(x)

x = tensorflow.keras.layers.UpSampling2D((2, 2))(encoded)
x = tensorflow.keras.layers.Conv2DTranspose(128, (3, 3), padding='same')(x)
x = tensorflow.keras.layers.LeakyReLU()(x)
x = tensorflow.keras.layers.UpSampling2D((2, 2))(x)
x = tensorflow.keras.layers.Conv2DTranspose(64, (3, 3), padding='same')(x)
x = tensorflow.keras.layers.LeakyReLU()(x)
x = tensorflow.keras.layers.UpSampling2D((2, 2))(x)
x = tensorflow.keras.layers.Conv2DTranspose(32, (3, 3), padding='same')(x)
x = tensorflow.keras.layers.LeakyReLU()(x)
decoded = tensorflow.keras.layers.Conv2DTranspose(3, (3, 3), padding='same')(x)

autoencoder = tensorflow.keras.Model(image_input, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.summary()


autoencoder.fit(dataset, dataset, epochs=50, shuffle=True, batch_size=BATCH_SIZE, validation_data=(val_dataset, val_dataset))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  leaky_re_lu (LeakyReLU)     (None, None, None, 32)    0
#
#  max_pooling2d (MaxPooling2D  (None, None, None, 32)   0
#  )
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, None, 64)    0
#
#  max_pooling2d_1 (MaxPooling  (None, None, None, 64)   0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 128)   73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, None, 128)   0
#
#  max_pooling2d_2 (MaxPooling  (None, None, None, 128)  0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, None, None, 2)     2306
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, None, 2)     0
#
#  up_sampling2d (UpSampling2D  (None, None, None, 2)    0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, None, None, 128)  2432
#  nspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, None, 128)   0
#
#  up_sampling2d_1 (UpSampling  (None, None, None, 128)  0
#  2D)
#
#  conv2d_transpose_1 (Conv2DT  (None, None, None, 64)   73792
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, None, 64)    0
#
#  up_sampling2d_2 (UpSampling  (None, None, None, 64)   0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, None, None, 32)   18464
#  ranspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, None, 32)    0
#
#  conv2d_transpose_3 (Conv2DT  (None, None, None, 3)    867
#  ranspose)
#
# =================================================================
# Total params: 191,109
# Trainable params: 191,109
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2024-04-19 01:55:44.388231: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8907
# 2024-04-19 01:55:44.737876: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-04-19 01:55:46.173233: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x952ffd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-19 01:55:46.173420: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Ti Laptop GPU, Compute Capability 8.6
# 2024-04-19 01:55:46.220334: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-19 01:55:46.593419: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-04-19 01:55:46.686637: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 235/235 [==============================] - 18s 49ms/step - loss: 0.0130 - val_loss: 0.0069
# Epoch 2/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 3/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 4/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 5/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 6/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 7/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 8/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 9/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 10/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 11/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 12/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 13/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 14/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 15/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 16/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 17/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 18/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 19/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 20/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 21/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 22/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 23/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 24/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 25/50
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 26/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 27/50
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 28/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 29/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 30/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 31/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 32/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 33/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 34/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 35/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 36/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 37/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 38/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 39/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 40/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 41/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 42/50
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 43/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 44/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 45/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 46/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 47/50
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 48/50
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 49/50
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 50/50
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0046 - val_loss: 0.0049

# %%
def pad_image(image: np.ndarray, patch_size: int):
    h, w, c = image.shape
    h_pad = (patch_size - (h % patch_size)) % patch_size
    w_pad = (patch_size - (w % patch_size)) % patch_size

    return np.pad(image, ((0, h_pad), (0, w_pad), (0, 0)), mode='constant', constant_values=0), h_pad, w_pad

# %%
image = tf.image.decode_image(tf.io.read_file('ciob.png'), channels=3, dtype='float32')

image_copy = image
image = tf.image.rgb_to_yuv(image)
image, h, w  = pad_image(image, 8)
image = tf.expand_dims(image, axis=0)

reconstructed_image_32 = autoencoder.predict(image)

image = tf.image.yuv_to_rgb(image)
image = tf.cast(image * 255, tf.uint8)

reconstructed_image_32 = tf.image.yuv_to_rgb(reconstructed_image_32)
reconstructed_image_32 = tf.cast(reconstructed_image_32 * 255, tf.uint8)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
# get rid of first dimension
image = tf.squeeze(image)
reconstructed_image_32 = tf.squeeze(reconstructed_image_32)

# %%
reconstructed_image_32 = reconstructed_image_32[:image_copy.shape[0], :image_copy.shape[1]]
image = image[:image_copy.shape[0], :image_copy.shape[1]]

print(image.shape)
print(reconstructed_image_32.shape)
# Out:
# (467, 396, 3)
# (467, 396, 3)

# %%
import matplotlib.pyplot as plt

ax, fig = plt.subplots(1, 2)
fig[0].imshow(image)
fig[1].imshow(reconstructed_image_32)

# %%
# compute psnr
tf.image.psnr(image, reconstructed_image_32, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=22.814281>

# %%
tf.image.ssim(image, reconstructed_image_32, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8342364>

# %%
tf.image.ssim_multiscale(image, reconstructed_image_32, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8880689>

# %%
encoder = tensorflow.keras.Model(image_input, encoded)

# %%
image = tf.image.decode_image(tf.io.read_file('ciob.png'), channels=3, dtype='float32')
image = tf.image.rgb_to_yuv(image)

image_, _, _ = pad_image(image, 8)

width = image_.shape[1]
height = image_.shape[0]

image_ = tf.expand_dims(image_, axis=0)

encoded_patches = encoder.predict(image_)
# Out:
# 1/1 [==============================] - 0s 437ms/step

# %%
encoded_patches = encoded_patches.astype(np.float16)
copy_encoded_patches = encoded_patches.copy()

# %%
decoder_input = tensorflow.keras.layers.Input(shape=(None, None, BINARY_SIZE))
decoder = tensorflow.keras.Model(encoded, decoded)

rec = decoder.predict(encoded_patches)
# Out:
# 1/1 [==============================] - 0s 80ms/step

# %%
rec.shape
# Out:
# (1, 472, 400, 3)

# %%
reconstructed_image_16 = tf.squeeze(rec)
reconstructed_image_16 = tf.image.yuv_to_rgb(reconstructed_image_16)

reconstructed_image_16 = reconstructed_image_16[:image.shape[0], :image.shape[1]]
reconstructed_image_16 = tf.convert_to_tensor(reconstructed_image_16)
reconstructed_image_16 = tf.cast(reconstructed_image_16 * 255, tf.uint8)

image = tf.image.yuv_to_rgb(image)
image = tf.cast(image * 255, tf.uint8)

# %%
print(image.shape)
print(reconstructed_image_16.shape)
# Out:
# (467, 396, 3)
# (467, 396, 3)

# %%
import matplotlib.pyplot as plt

ax, fig = plt.subplots(1, 2)
fig[0].imshow(image)
fig[1].imshow(reconstructed_image_16)

# %%
tf.image.psnr(image, reconstructed_image_16, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=22.814842>

# %%
tf.image.ssim(image, reconstructed_image_16, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8342516>

# %%
tf.image.ssim_multiscale(image, reconstructed_image_16, max_val=255)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8880748>

# %%
encoded_patches.shape
# Out:
# (1, 59, 50, 2)
